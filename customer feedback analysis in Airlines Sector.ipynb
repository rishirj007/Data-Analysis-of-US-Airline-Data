# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv(r"C:\Users\rishi ranjan jha\Downloads\us airline data.csv")

# %%
a.head()
# Out:
#        tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  5.700000e+17           neutral                        1.0000
# 1  5.700000e+17          positive                        0.3486
# 2  5.700000e+17           neutral                        0.6837
# 3  5.700000e+17          negative                        1.0000
# 4  5.700000e+17          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# ...

# %%
a.shape
# Out:
# (14640, 15)

# %%
a[(a['airline_sentiment']=='negative')]['name']
# Out:
# 3               jnardino
# 4               jnardino
# 5               jnardino
# 15       smartwatermelon
# 17         heatherovieda
#               ...
# 14631           MDDavis7
# 14633    RussellsWriting
# 14634      GolfWithWoody
# 14636           itsropes
# 14638         SraJackson
# Name: name, Length: 9178, dtype: object

# %%
a[(a['airline_sentiment']=='negative')]['name'].tolist()
# Out:
# ['jnardino',
#  'jnardino',
#  'jnardino',
#  'smartwatermelon',
#  'heatherovieda',
#  'MISSGJ',
#  'ayeevickiee',
#  'Leora13',
#  'meredithjlynn',
#  'blackjackpro911',
#  'jordanpichler',
#  'Cuschoolie1',
#  'amanduhmccarty',
#  'DannyDouglass',
#  'will_lenzenjr',
#  'murphicus',
#  'rachie1126',
#  'onerockgypsy',
#  'noelduan',
#  'gianagon',
#  'seimatrun',
#  'meme_meng',
#  'GunsNDip',
#  'arieldaie',
#  'GunsNDip',
#  'GunsNDip',
#  'jsatk',
#  'MaryAnnTaylorT',
#  'AlisonK33774854',
#  'GunsNDip',
#  'MerchEngines',
#  'ColorCartel',
#  'MustBeSpoken',
#  'mattbunk',
#  'louisjenny',
#  'GunsNDip',
#  'mrmichaellay',
#  'GunsNDip',
#  'BeLeather',
#  'BeLeather',
#  'nicholas_v',
#  'usagibrian',
#  'usagibrian',
#  'KindofLuke',
#  'ChrisFordisHere',
#  'melokudo',
#  'ChrysiChrysic',
#  'ChrysiChrysic',
#  'MOCBlogger',
#  'tfaz',
#  'GoShar2012',
#  'MOCBlogger',
#  'jarrydosborne',
#  'mlorenzen',
#  'Tyler_Starrine',
#  'khartline',
#  'khartline',
#  'paulnakada',
# ...

# %%
plt.plot(a['airline_sentiment'],a['name'])
plt.show()

# %%
plt.figure(1 , figsize = (16 , 9))
sns.heatmap(a.corr(), annot = True)

# %%
plt.figure(figsize=(16,9))
sns.heatmap(a.isnull(), yticklabels = False, cmap = 'winter')

# %%
a.isnull().sum()
# Out:
# tweet_id                            0
# airline_sentiment                   0
# airline_sentiment_confidence        0
# negativereason                   5462
# negativereason_confidence        4118
# airline                             0
# airline_sentiment_gold          14600
# name                                0
# negativereason_gold             14608
# retweet_count                       0
# text                                0
# tweet_coord                     13621
# tweet_created                       0
# tweet_location                   4733
# user_timezone                    4820
# dtype: int64

# %%
a.dropna(inplace=True)

# %%
a.isnull().sum()
# Out:
# tweet_id                        0
# airline_sentiment               0
# airline_sentiment_confidence    0
# negativereason                  0
# negativereason_confidence       0
# airline                         0
# airline_sentiment_gold          0
# name                            0
# negativereason_gold             0
# retweet_count                   0
# text                            0
# tweet_coord                     0
# tweet_created                   0
# tweet_location                  0
# user_timezone                   0
# dtype: int64

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 4206 to 9536
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tweet_id                      2 non-null      float64
#  1   airline_sentiment             2 non-null      object
#  2   airline_sentiment_confidence  2 non-null      float64
#  3   negativereason                2 non-null      object
#  4   negativereason_confidence     2 non-null      float64
#  5   airline                       2 non-null      object
#  6   airline_sentiment_gold        2 non-null      object
#  7   name                          2 non-null      object
#  8   negativereason_gold           2 non-null      object
#  9   retweet_count                 2 non-null      int64
#  10  text                          2 non-null      object
#  11  tweet_coord                   2 non-null      object
# ...

# %%
a.describe()
# Out:
#            tweet_id  airline_sentiment_confidence  negativereason_confidence  \
# count  2.000000e+00                      2.000000                   2.000000
# mean   5.690000e+17                      0.928150                   0.796900
# std    1.414214e+15                      0.101611                   0.287227
# min    5.680000e+17                      0.856300                   0.593800
# 25%    5.685000e+17                      0.892225                   0.695350
# 50%    5.690000e+17                      0.928150                   0.796900
# 75%    5.695000e+17                      0.964075                   0.898450
# max    5.700000e+17                      1.000000                   1.000000
#
#        retweet_count
# count            2.0
# mean             0.0
# std              0.0
# min              0.0
# 25%              0.0
# 50%              0.0
# 75%              0.0
# max              0.0

# %%
print("Total number of columns containing null values are : ")
print(len(a.columns[a.isna().any()]))
# Out:
# Total number of columns containing null values are :
# 0

# %%
plt.scatter(a['airline_sentiment'][0:1000],a['name'][0:1000])
plt.show()

# %%
e=a['tweet_location'].unique().tolist()
e
# Out:
# ['Chicago', 'Boston, MA']

# %%
a['airline'].unique().tolist()
# Out:
# ['United', 'US Airways']

# %%
c=a[(a['airline']=='Virgin America')]['name'].count()
c
# Out:
# 0

# %%
plt.plot((a['airline']=='Virgin America'),a['name'])
plt.show()

# %%
d=a[(a['airline']=='United')]['name'].count()
d
# Out:
# 1

# %%
plt.plot((a['airline']=='United'),a['name'])
plt.show()

# %%
e=a[(a['airline']=='US Airways')]['name'].count()
e
# Out:
# 1

# %%
plt.plot((a['airline']=='US Airways'),a['name'])
plt.show()

# %%
f=a[(a['airline']=='Southwest')]['name'].count()
f
# Out:
# 0

# %%
plt.plot((a['airline']=='Southwest'),a['name'])
plt.show()

# %%
a['airline_sentiment_confidence'].mean()
# Out:
# 0.92815

# %%
a['user_timezone'].unique().tolist()
# Out:
# ['Eastern Time (US & Canada)', 'Atlantic Time (Canada)']

# %%
plt.plot(a['airline_sentiment_confidence'][0:1000],a['name'][0:1000])
plt.show()

# %%
plt.plot(a['airline'][0:1000],a['name'][0:1000])
plt.show()
